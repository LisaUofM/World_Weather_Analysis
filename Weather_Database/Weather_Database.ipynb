# %%
import random

# %%
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs
#zips into tuple

# %%
coordinates = list(lat_lngs)

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
from citipy import citipy

# %%
#Get the nearest city

cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)
        
len(cities)
# Out:
# 612

# %%
import requests

from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f9c6a9780b91951d793a52dea54d68ef

# %%
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Out:
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | narsaq
# Processing Record 3 of Set 1 | cidreira
# Processing Record 4 of Set 1 | faanui
# Processing Record 5 of Set 1 | hilo
# Processing Record 6 of Set 1 | lagoa
# Processing Record 7 of Set 1 | san cristobal
# Processing Record 8 of Set 1 | taolanaro
# Processing Record 9 of Set 1 | vaini
# Processing Record 10 of Set 1 | sao joao da barra
# Processing Record 11 of Set 1 | lasa
# Processing Record 12 of Set 1 | ossora
# Processing Record 13 of Set 1 | utiroa
# Processing Record 14 of Set 1 | tiksi
# Processing Record 15 of Set 1 | gisborne
# Processing Record 16 of Set 1 | bredasdorp
# Processing Record 17 of Set 1 | thompson
# Processing Record 18 of Set 1 | sakmara
# Processing Record 19 of Set 1 | camabatela
# Processing Record 20 of Set 1 | kapaa
# Processing Record 21 of Set 1 | hermanus
# Processing Record 22 of Set 1 | khudumelapye
# Processing Record 23 of Set 1 | rikitea
# Processing Record 24 of Set 1 | ushuaia
# Processing Record 25 of Set 1 | nalut
# Processing Record 26 of Set 1 | avarua
# Processing Record 27 of Set 1 | nanortalik
# Processing Record 28 of Set 1 | broken hill
# Processing Record 29 of Set 1 | pisco
# Processing Record 30 of Set 1 | colomi
# Processing Record 31 of Set 1 | birjand
# Processing Record 32 of Set 1 | heihe
# Processing Record 33 of Set 1 | butaritari
# Processing Record 34 of Set 1 | saskylakh
# Processing Record 35 of Set 1 | breyten
# Processing Record 36 of Set 1 | bluff
# Processing Record 37 of Set 1 | barentsburg
# Processing Record 38 of Set 1 | albany
# Processing Record 39 of Set 1 | puerto ayora
# Processing Record 40 of Set 1 | beian
# Processing Record 41 of Set 1 | kaitangata
# Processing Record 42 of Set 1 | uyuni
# Processing Record 43 of Set 1 | belushya guba
# Processing Record 44 of Set 1 | ancud
# Processing Record 45 of Set 1 | nikolskoye
# Processing Record 46 of Set 1 | marcona
# Processing Record 47 of Set 1 | mataura
# Processing Record 48 of Set 1 | castro
# Processing Record 49 of Set 1 | east london
# Processing Record 50 of Set 1 | atuona
# Processing Record 1 of Set 2 | half moon bay
# Processing Record 2 of Set 2 | hobart
# Processing Record 3 of Set 2 | colares
# Processing Record 4 of Set 2 | kavaratti
# Processing Record 5 of Set 2 | ponta do sol
# Processing Record 6 of Set 2 | cape town
# Processing Record 7 of Set 2 | dolbeau
# Processing Record 8 of Set 2 | amderma
# Processing Record 9 of Set 2 | polovinnoye
# Processing Record 10 of Set 2 | mount gambier
# Processing Record 11 of Set 2 | kruisfontein
# Processing Record 12 of Set 2 | la seyne-sur-mer
# Processing Record 13 of Set 2 | port elizabeth
# Processing Record 14 of Set 2 | homer
# Processing Record 15 of Set 2 | tuktoyaktuk
# Processing Record 16 of Set 2 | port lincoln
# Processing Record 17 of Set 2 | manggar
# Processing Record 18 of Set 2 | tasiilaq
# Processing Record 19 of Set 2 | new norfolk
# Processing Record 20 of Set 2 | takoradi
# Processing Record 21 of Set 2 | jamestown
# Processing Record 22 of Set 2 | georgetown
# Processing Record 23 of Set 2 | alice springs
# Processing Record 24 of Set 2 | chiang khong
# Processing Record 25 of Set 2 | padang
# Processing Record 26 of Set 2 | klaksvik
# Processing Record 27 of Set 2 | saint-philippe
# Processing Record 28 of Set 2 | namibe
# Processing Record 29 of Set 2 | eidfjord
# Processing Record 30 of Set 2 | sokolo
# Processing Record 31 of Set 2 | damaturu
# Processing Record 32 of Set 2 | kahului
# Processing Record 33 of Set 2 | kodarma
# Processing Record 34 of Set 2 | linares
# Processing Record 35 of Set 2 | rosetown
# Processing Record 36 of Set 2 | lompoc
# Processing Record 37 of Set 2 | rio gallegos
# Processing Record 38 of Set 2 | biak
# Processing Record 39 of Set 2 | barrow
# Processing Record 40 of Set 2 | mahebourg
# Processing Record 41 of Set 2 | minot
# Processing Record 42 of Set 2 | altay
# Processing Record 43 of Set 2 | auki
# Processing Record 44 of Set 2 | dakar
# Processing Record 45 of Set 2 | naze
# Processing Record 46 of Set 2 | san pedro
# Processing Record 47 of Set 2 | hithadhoo
# Processing Record 48 of Set 2 | illoqqortoormiut
# Processing Record 49 of Set 2 | arlit
# Processing Record 50 of Set 2 | guadalupe y calvo
# Processing Record 1 of Set 3 | the valley
# Processing Record 2 of Set 3 | la palma
# Processing Record 3 of Set 3 | halifax
# Processing Record 4 of Set 3 | manaquiri
# Processing Record 5 of Set 3 | severo-kurilsk
# Processing Record 6 of Set 3 | vila
# Processing Record 7 of Set 3 | leningradskiy
# Processing Record 8 of Set 3 | russell
# Processing Record 9 of Set 3 | waddan
# Processing Record 10 of Set 3 | katangli
# Processing Record 11 of Set 3 | sentyabrskiy
# Processing Record 12 of Set 3 | zhigansk
# Processing Record 13 of Set 3 | upernavik
# Processing Record 14 of Set 3 | yellowknife
# Processing Record 15 of Set 3 | tessalit
# Processing Record 16 of Set 3 | itarema
# Processing Record 17 of Set 3 | chokurdakh
# Processing Record 18 of Set 3 | palmer
# Processing Record 19 of Set 3 | kemijarvi
# Processing Record 20 of Set 3 | ilulissat
# Processing Record 21 of Set 3 | road town
# Processing Record 22 of Set 3 | bambous virieux
# Processing Record 23 of Set 3 | qaanaaq
# Processing Record 24 of Set 3 | nizhneyansk
# Processing Record 25 of Set 3 | port augusta
# Processing Record 26 of Set 3 | fortuna
# Processing Record 27 of Set 3 | ladario
# Processing Record 28 of Set 3 | airai
# Processing Record 29 of Set 3 | vostok
# Processing Record 30 of Set 3 | mar del plata
# Processing Record 31 of Set 3 | ust-nera
# Processing Record 32 of Set 3 | yulara
# Processing Record 33 of Set 3 | esperance
# Processing Record 34 of Set 3 | hamilton
# Processing Record 35 of Set 3 | qaqortoq
# Processing Record 36 of Set 3 | pacific grove
# Processing Record 37 of Set 3 | springfield
# Processing Record 38 of Set 3 | huejuquilla el alto
# Processing Record 39 of Set 3 | rio tercero
# Processing Record 40 of Set 3 | pevek
# Processing Record 41 of Set 3 | russkiy aktash
# Processing Record 42 of Set 3 | avera
# Processing Record 43 of Set 3 | busselton
# Processing Record 44 of Set 3 | deputatskiy
# Processing Record 45 of Set 3 | jumla
# Processing Record 46 of Set 3 | wanaka
# Processing Record 47 of Set 3 | noyabrsk
# Processing Record 48 of Set 3 | agadez
# Processing Record 49 of Set 3 | port alfred
# Processing Record 50 of Set 3 | san angelo
# Processing Record 1 of Set 4 | kalianget
# Processing Record 2 of Set 4 | kindu
# Processing Record 3 of Set 4 | new castle
# Processing Record 4 of Set 4 | novoagansk
# Processing Record 5 of Set 4 | saldanha
# Processing Record 6 of Set 4 | bethel
# Processing Record 7 of Set 4 | jabiru
# Processing Record 8 of Set 4 | ferrol
# Processing Record 9 of Set 4 | progreso
# Processing Record 10 of Set 4 | leninsk
# Processing Record 11 of Set 4 | ilinskiy
# Processing Record 12 of Set 4 | grand river south east
# Processing Record 13 of Set 4 | los llanos de aridane
# Processing Record 14 of Set 4 | buala
# Processing Record 15 of Set 4 | kaohsiung
# Processing Record 16 of Set 4 | carnarvon
# Processing Record 17 of Set 4 | maraa
# Processing Record 18 of Set 4 | pafos
# Processing Record 19 of Set 4 | bandar-e anzali
# Processing Record 20 of Set 4 | riyadh
# Processing Record 21 of Set 4 | mehamn
# Processing Record 22 of Set 4 | ahipara
# Processing Record 23 of Set 4 | khash
# Processing Record 24 of Set 4 | mmathubudukwane
# Processing Record 25 of Set 4 | ushtobe
# Processing Record 26 of Set 4 | cruz alta
# Processing Record 27 of Set 4 | grindavik
# Processing Record 28 of Set 4 | akyab
# Processing Record 29 of Set 4 | napoleon
# Processing Record 30 of Set 4 | talcahuano
# Processing Record 31 of Set 4 | cockburn town
# Processing Record 32 of Set 4 | khatanga
# Processing Record 33 of Set 4 | san patricio
# Processing Record 34 of Set 4 | vila velha
# Processing Record 35 of Set 4 | laguna
# Processing Record 36 of Set 4 | ribeira grande
# Processing Record 37 of Set 4 | geraldton
# Processing Record 38 of Set 4 | college
# Processing Record 39 of Set 4 | altar
# Processing Record 40 of Set 4 | ormara
# Processing Record 41 of Set 4 | lavrentiya
# Processing Record 42 of Set 4 | sambava
# Processing Record 43 of Set 4 | perle
# Processing Record 44 of Set 4 | jensen beach
# Processing Record 45 of Set 4 | torbay
# Processing Record 46 of Set 4 | casper
# Processing Record 47 of Set 4 | bosobolo
# Processing Record 48 of Set 4 | quesnel
# Processing Record 49 of Set 4 | kovdor
# Processing Record 50 of Set 4 | dikson
# Processing Record 1 of Set 5 | cap malheureux
# Processing Record 2 of Set 5 | komsomolskiy
# Processing Record 3 of Set 5 | sao filipe
# Processing Record 4 of Set 5 | yumen
# Processing Record 5 of Set 5 | montepuez
# Processing Record 6 of Set 5 | cabo san lucas
# Processing Record 7 of Set 5 | tsihombe
# Processing Record 8 of Set 5 | huarmey
# Processing Record 9 of Set 5 | kommunisticheskiy
# Processing Record 10 of Set 5 | norman wells
# Processing Record 11 of Set 5 | kodiak
# Processing Record 12 of Set 5 | dentsville
# Processing Record 13 of Set 5 | kendari
# Processing Record 14 of Set 5 | souillac
# Processing Record 15 of Set 5 | comodoro rivadavia
# Processing Record 16 of Set 5 | ukiah
# Processing Record 17 of Set 5 | lebu
# Processing Record 18 of Set 5 | maceio
# Processing Record 19 of Set 5 | ternate
# Processing Record 20 of Set 5 | te anau
# Processing Record 21 of Set 5 | honiara
# Processing Record 22 of Set 5 | ust-bolsheretsk
# Processing Record 23 of Set 5 | waingapu
# Processing Record 24 of Set 5 | sola
# Processing Record 25 of Set 5 | raudeberg
# Processing Record 26 of Set 5 | santa lucia
# Processing Record 27 of Set 5 | port hedland
# Processing Record 28 of Set 5 | quatre cocos
# Processing Record 29 of Set 5 | guerrero negro
# Processing Record 30 of Set 5 | victoria
# Processing Record 31 of Set 5 | lieksa
# Processing Record 32 of Set 5 | hualmay
# Processing Record 33 of Set 5 | fort nelson
# Processing Record 34 of Set 5 | tabiauea
# Processing Record 35 of Set 5 | meulaboh
# Processing Record 36 of Set 5 | gemena
# Processing Record 37 of Set 5 | saleaula
# Processing Record 38 of Set 5 | dunmore town
# Processing Record 39 of Set 5 | wajima
# Processing Record 40 of Set 5 | leh
# Processing Record 41 of Set 5 | sitka
# Processing Record 42 of Set 5 | samusu
# Processing Record 43 of Set 5 | kisangani
# Processing Record 44 of Set 5 | longyearbyen
# Processing Record 45 of Set 5 | banda aceh
# Processing Record 46 of Set 5 | surt
# Processing Record 47 of Set 5 | canyon
# Processing Record 48 of Set 5 | strezhevoy
# Processing Record 49 of Set 5 | juifang
# Processing Record 50 of Set 5 | moerai
# Processing Record 1 of Set 6 | dillon
# Processing Record 2 of Set 6 | vanimo
# Processing Record 3 of Set 6 | trat
# Processing Record 4 of Set 6 | kut chap
# Processing Record 5 of Set 6 | vardo
# Processing Record 6 of Set 6 | olovyannaya
# Processing Record 7 of Set 6 | gladstone
# Processing Record 8 of Set 6 | terrasini
# Processing Record 9 of Set 6 | hasaki
# Processing Record 10 of Set 6 | kuandian
# Processing Record 11 of Set 6 | rawannawi
# Processing Record 12 of Set 6 | havre-saint-pierre
# Processing Record 13 of Set 6 | arraial do cabo
# Processing Record 14 of Set 6 | sao jose da coroa grande
# Processing Record 15 of Set 6 | kieta
# Processing Record 16 of Set 6 | vaitape
# Processing Record 17 of Set 6 | epe
# Processing Record 18 of Set 6 | ambon
# Processing Record 19 of Set 6 | demba
# Processing Record 20 of Set 6 | ponta delgada
# Processing Record 21 of Set 6 | beringovskiy
# Processing Record 22 of Set 6 | porkhov
# Processing Record 23 of Set 6 | emerald
# Processing Record 24 of Set 6 | osakarovka
# Processing Record 25 of Set 6 | hanmer springs
# Processing Record 26 of Set 6 | san ramon
# Processing Record 27 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 28 of Set 6 | tateyama
# Processing Record 29 of Set 6 | ondangwa
# Processing Record 30 of Set 6 | tanout
# Processing Record 31 of Set 6 | ellisras
# Processing Record 32 of Set 6 | port hardy
# Processing Record 33 of Set 6 | charlestown
# Processing Record 34 of Set 6 | tanabe
# Processing Record 35 of Set 6 | peniche
# Processing Record 36 of Set 6 | port hawkesbury
# Processing Record 37 of Set 6 | louisbourg
# Processing Record 38 of Set 6 | vaitupu
# Processing Record 39 of Set 6 | dingle
# Processing Record 40 of Set 6 | nome
# Processing Record 41 of Set 6 | bilma
# Processing Record 42 of Set 6 | attawapiskat
# Processing Record 43 of Set 6 | tarpon springs
# Processing Record 44 of Set 6 | gumushane
# Processing Record 45 of Set 6 | ulagan
# Processing Record 46 of Set 6 | grand centre
# Processing Record 47 of Set 6 | seymchan
# Processing Record 48 of Set 6 | nishihara
# Processing Record 49 of Set 6 | inta
# Processing Record 50 of Set 6 | flin flon
# Processing Record 1 of Set 7 | chuy
# Processing Record 2 of Set 7 | mumbwa
# Processing Record 3 of Set 7 | acarau
# Processing Record 4 of Set 7 | lorica
# Processing Record 5 of Set 7 | coihaique
# Processing Record 6 of Set 7 | bonavista
# Processing Record 7 of Set 7 | pudozh
# Processing Record 8 of Set 7 | villazon
# Processing Record 9 of Set 7 | parakan
# Processing Record 10 of Set 7 | valleyview
# Processing Record 11 of Set 7 | saint-pierre
# Processing Record 12 of Set 7 | kavieng
# Processing Record 13 of Set 7 | zvolen
# Processing Record 14 of Set 7 | minuri
# Processing Record 15 of Set 7 | sauca
# Processing Record 16 of Set 7 | sungairaya
# Processing Record 17 of Set 7 | itoman
# Processing Record 18 of Set 7 | kuryk
# Processing Record 19 of Set 7 | charters towers
# Processing Record 20 of Set 7 | kismayo
# Processing Record 21 of Set 7 | grand gaube
# Processing Record 22 of Set 7 | enumclaw
# Processing Record 23 of Set 7 | vitim
# Processing Record 24 of Set 7 | antalaha
# Processing Record 25 of Set 7 | cayenne
# Processing Record 26 of Set 7 | buraydah
# Processing Record 27 of Set 7 | anzio
# Processing Record 28 of Set 7 | huazolotitlan
# Processing Record 29 of Set 7 | grand-santi
# Processing Record 30 of Set 7 | san carlos del zulia
# Processing Record 31 of Set 7 | weligama
# Processing Record 32 of Set 7 | yining
# Processing Record 33 of Set 7 | lima
# Processing Record 34 of Set 7 | bubaque
# Processing Record 35 of Set 7 | goderich
# Processing Record 36 of Set 7 | dhanera
# Processing Record 37 of Set 7 | nicolas bravo
# Processing Record 38 of Set 7 | cherskiy
# Processing Record 39 of Set 7 | aksarka
# Processing Record 40 of Set 7 | yar-sale
# Processing Record 41 of Set 7 | kharan
# Processing Record 42 of Set 7 | kamenskoye
# Processing Record 43 of Set 7 | straumen
# Processing Record 44 of Set 7 | dzhusaly
# Processing Record 45 of Set 7 | laurel
# Processing Record 46 of Set 7 | lac du bonnet
# Processing Record 47 of Set 7 | provideniya
# Processing Record 48 of Set 7 | palana
# Processing Record 49 of Set 7 | moron
# Processing Record 50 of Set 7 | javanrud
# Processing Record 1 of Set 8 | san quintin
# Processing Record 2 of Set 8 | bandarbeyla
# Processing Record 3 of Set 8 | rocha
# Processing Record 4 of Set 8 | boqueirao
# Processing Record 5 of Set 8 | toftir
# Processing Record 6 of Set 8 | san-pedro
# Processing Record 7 of Set 8 | lodwar
# Processing Record 8 of Set 8 | monteria
# Processing Record 9 of Set 8 | constitucion
# Processing Record 10 of Set 8 | abha
# Processing Record 11 of Set 8 | rungata
# Processing Record 12 of Set 8 | grande prairie
# Processing Record 13 of Set 8 | milan
# Processing Record 14 of Set 8 | dukat
# Processing Record 15 of Set 8 | ampanihy
# Processing Record 16 of Set 8 | ritchie
# Processing Record 17 of Set 8 | fukuma
# Processing Record 18 of Set 8 | esso
# Processing Record 19 of Set 8 | umm durman
# Processing Record 20 of Set 8 | damoh
# Processing Record 21 of Set 8 | terra santa
# Processing Record 22 of Set 8 | luganville
# Processing Record 23 of Set 8 | talaya
# Processing Record 24 of Set 8 | svetlaya
# Processing Record 25 of Set 8 | sibolga
# Processing Record 26 of Set 8 | bismarck
# Processing Record 27 of Set 8 | lumby
# Processing Record 28 of Set 8 | zyryanka
# Processing Record 29 of Set 8 | marawi
# Processing Record 30 of Set 8 | evanston
# Processing Record 31 of Set 8 | hobyo
# Processing Record 32 of Set 8 | tocopilla
# Processing Record 33 of Set 8 | makungu
# Processing Record 34 of Set 8 | dali
# Processing Record 35 of Set 8 | ust-kan
# Processing Record 36 of Set 8 | trinidad
# Processing Record 37 of Set 8 | srivardhan
# Processing Record 38 of Set 8 | warqla
# Processing Record 39 of Set 8 | kasempa
# Processing Record 40 of Set 8 | port dickson
# Processing Record 41 of Set 8 | verkhnevilyuysk
# Processing Record 42 of Set 8 | erdenet
# Processing Record 43 of Set 8 | bathsheba
# Processing Record 44 of Set 8 | turtkul
# Processing Record 45 of Set 8 | hailar
# Processing Record 46 of Set 8 | rundu
# Processing Record 47 of Set 8 | marsaxlokk
# Processing Record 48 of Set 8 | jarjis
# Processing Record 49 of Set 8 | touros
# Processing Record 50 of Set 8 | orai
# Processing Record 1 of Set 9 | ostrovnoy
# Processing Record 2 of Set 9 | shush
# Processing Record 3 of Set 9 | barra patuca
# Processing Record 4 of Set 9 | mrakovo
# Processing Record 5 of Set 9 | visby
# Processing Record 6 of Set 9 | urdzhar
# Processing Record 7 of Set 9 | barabai
# Processing Record 8 of Set 9 | presidente dutra
# Processing Record 9 of Set 9 | saint george
# Processing Record 10 of Set 9 | vanavara
# Processing Record 11 of Set 9 | nuuk
# Processing Record 12 of Set 9 | atar
# Processing Record 13 of Set 9 | sattahip
# Processing Record 14 of Set 9 | katsuura
# Processing Record 15 of Set 9 | praia da vitoria
# Processing Record 16 of Set 9 | ust-kamchatsk
# Processing Record 17 of Set 9 | amarpur
# Processing Record 18 of Set 9 | shushtar
# Processing Record 19 of Set 9 | mindelo
# Processing Record 20 of Set 9 | prince george
# Processing Record 21 of Set 9 | ngunguru
# Processing Record 22 of Set 9 | mogilno
# Processing Record 23 of Set 9 | jambi
# Processing Record 24 of Set 9 | tholen
# Processing Record 25 of Set 9 | linxia
# Processing Record 26 of Set 9 | melo
# Processing Record 27 of Set 9 | puerto del rosario
# Processing Record 28 of Set 9 | mys shmidta
# Processing Record 29 of Set 9 | tambul
# Processing Record 30 of Set 9 | karkaralinsk
# Processing Record 31 of Set 9 | galveston
# Processing Record 32 of Set 9 | nuevitas
# Processing Record 33 of Set 9 | numan
# Processing Record 34 of Set 9 | umtata
# Processing Record 35 of Set 9 | northam
# Processing Record 36 of Set 9 | labuhan
# Processing Record 37 of Set 9 | ulaangom
# Processing Record 38 of Set 9 | benguela
# Processing Record 39 of Set 9 | komarikhinskiy
# Processing Record 40 of Set 9 | formosa do rio preto
# Processing Record 41 of Set 9 | copala
# Processing Record 42 of Set 9 | chapais
# Processing Record 43 of Set 9 | stromness
# Processing Record 44 of Set 9 | parras
# Processing Record 45 of Set 9 | berlevag
# Processing Record 46 of Set 9 | labutta
# Processing Record 47 of Set 9 | erenhot
# Processing Record 48 of Set 9 | balimo
# Processing Record 49 of Set 9 | jinchang
# Processing Record 50 of Set 9 | killybegs
# Processing Record 1 of Set 10 | paamiut
# Processing Record 2 of Set 10 | samalaeulu
# Processing Record 3 of Set 10 | husavik
# Processing Record 4 of Set 10 | faya
# Processing Record 5 of Set 10 | dimona
# Processing Record 6 of Set 10 | vestmanna
# Processing Record 7 of Set 10 | calatayud
# Processing Record 8 of Set 10 | ondorhaan
# Processing Record 9 of Set 10 | margate
# Processing Record 10 of Set 10 | sheregesh
# Processing Record 11 of Set 10 | ballina
# Processing Record 12 of Set 10 | igarka
# Processing Record 13 of Set 10 | uglovskoye
# Processing Record 14 of Set 10 | edgewater
# Processing Record 15 of Set 10 | olafsvik
# Processing Record 16 of Set 10 | atambua
# Processing Record 17 of Set 10 | kloulklubed
# Processing Record 18 of Set 10 | bacuit
# Processing Record 19 of Set 10 | marsh harbour
# Processing Record 20 of Set 10 | hambantota
# Processing Record 21 of Set 10 | tezu
# Processing Record 22 of Set 10 | gushikawa
# Processing Record 23 of Set 10 | krabi
# Processing Record 24 of Set 10 | zeya
# Processing Record 25 of Set 10 | repnoye
# Processing Record 26 of Set 10 | samandag
# Processing Record 27 of Set 10 | alexandria
# Processing Record 28 of Set 10 | saint-augustin
# Processing Record 29 of Set 10 | dicabisagan
# Processing Record 30 of Set 10 | copperas cove
# Processing Record 31 of Set 10 | pangoa
# Processing Record 32 of Set 10 | mbandaka
# Processing Record 33 of Set 10 | vryburg
# Processing Record 34 of Set 10 | karaul
# Processing Record 35 of Set 10 | jalu
# Processing Record 36 of Set 10 | abu dhabi
# Processing Record 37 of Set 10 | kumylzhenskaya
# Processing Record 38 of Set 10 | saint anthony
# Processing Record 39 of Set 10 | luzhou
# Processing Record 40 of Set 10 | richards bay
# Processing Record 41 of Set 10 | shitanjing
# Processing Record 42 of Set 10 | patan
# Processing Record 43 of Set 10 | tuatapere
# Processing Record 44 of Set 10 | codrington
# Processing Record 45 of Set 10 | show low
# Processing Record 46 of Set 10 | nabire
# Processing Record 47 of Set 10 | tautira
# Processing Record 48 of Set 10 | lucknow
# Processing Record 49 of Set 10 | vagur
# Processing Record 50 of Set 10 | guararapes
# Processing Record 1 of Set 11 | turayf
# Processing Record 2 of Set 11 | bolungarvik
# Processing Record 3 of Set 11 | puerto colombia
# Processing Record 4 of Set 11 | giyon
# Processing Record 5 of Set 11 | atasu
# Processing Record 6 of Set 11 | lorengau
# Processing Record 7 of Set 11 | nizwa
# Processing Record 8 of Set 11 | jiddah
# Processing Record 9 of Set 11 | koslan
# Processing Record 10 of Set 11 | kaligutan
# Processing Record 11 of Set 11 | chagda
# Processing Record 12 of Set 11 | hofn
# Processing Record 13 of Set 11 | magdagachi
# Processing Record 14 of Set 11 | buchanan
# Processing Record 15 of Set 11 | bilibino
# Processing Record 16 of Set 11 | belaya gora
# Processing Record 17 of Set 11 | tawkar
# Processing Record 18 of Set 11 | trelew
# Processing Record 19 of Set 11 | shaoyang
# Processing Record 20 of Set 11 | caborca
# Processing Record 21 of Set 11 | billings
# Processing Record 22 of Set 11 | port blair
# Processing Record 23 of Set 11 | poso
# Processing Record 24 of Set 11 | westport
# Processing Record 25 of Set 11 | mtwara
# Processing Record 26 of Set 11 | sioux lookout
# Processing Record 27 of Set 11 | sarangani
# Processing Record 28 of Set 11 | harrison
# Processing Record 29 of Set 11 | orje
# Processing Record 30 of Set 11 | stokmarknes
# Processing Record 31 of Set 11 | teahupoo
# Processing Record 32 of Set 11 | sayyan
# Processing Record 33 of Set 11 | paulo ramos
# Processing Record 34 of Set 11 | santa cruz
# Processing Record 35 of Set 11 | yuzhno-yeniseyskiy
# Processing Record 36 of Set 11 | kondoa
# Processing Record 37 of Set 11 | raduzhnyy
# Processing Record 38 of Set 11 | bikaner
# Processing Record 39 of Set 11 | clyde river
# Processing Record 40 of Set 11 | markova
# Processing Record 41 of Set 11 | halalo
# Processing Record 42 of Set 11 | alba
# Processing Record 43 of Set 11 | pangody
# Processing Record 44 of Set 11 | monrovia
# Processing Record 45 of Set 11 | oum hadjer
# Processing Record 46 of Set 11 | soyo
# Processing Record 47 of Set 11 | manavalakurichi
# Processing Record 48 of Set 11 | ulladulla
# Processing Record 49 of Set 11 | cagayan de tawi-tawi
# Processing Record 50 of Set 11 | necochea
# Processing Record 1 of Set 12 | hanyang
# Processing Record 2 of Set 12 | oistins
# Processing Record 3 of Set 12 | ouallam
# Processing Record 4 of Set 12 | salalah
# Processing Record 5 of Set 12 | san agustin
# Processing Record 6 of Set 12 | samarai
# Processing Record 7 of Set 12 | taywarah
# Processing Record 8 of Set 12 | karratha
# Processing Record 9 of Set 12 | jining
# Processing Record 10 of Set 12 | virginia beach
# Processing Record 11 of Set 12 | lamu
# Processing Record 12 of Set 12 | evensk
# Processing Record 13 of Set 12 | anadyr
# Processing Record 14 of Set 12 | gat
# Processing Record 15 of Set 12 | kamenka
# Processing Record 16 of Set 12 | oriximina
# Processing Record 17 of Set 12 | broome
# Processing Record 18 of Set 12 | naifaru
# Processing Record 19 of Set 12 | mgandu
# Processing Record 20 of Set 12 | lungi
# Processing Record 21 of Set 12 | sibenik
# Processing Record 22 of Set 12 | robertsport
# Processing Record 23 of Set 12 | zhuhai
# Processing Record 24 of Set 12 | nobeoka
# Processing Record 25 of Set 12 | sakakah
# Processing Record 26 of Set 12 | antropovo
# Processing Record 27 of Set 12 | krasnoselkup
# Processing Record 28 of Set 12 | ihosy
# Processing Record 29 of Set 12 | mokhsogollokh
# Processing Record 30 of Set 12 | ariquemes
# Processing Record 31 of Set 12 | kiunga
# Processing Record 32 of Set 12 | aykhal
# Processing Record 33 of Set 12 | bonthe
# Processing Record 34 of Set 12 | severnyy
# Processing Record 35 of Set 12 | tecoanapa
# Processing Record 36 of Set 12 | rapar
# Processing Record 37 of Set 12 | sorvag
# Processing Record 38 of Set 12 | poopo
# Processing Record 39 of Set 12 | wanning
# Processing Record 40 of Set 12 | cornelio procopio
# Processing Record 41 of Set 12 | ust-barguzin
# Processing Record 42 of Set 12 | coahuayana
# Processing Record 43 of Set 12 | presidencia roque saenz pena
# Processing Record 44 of Set 12 | adrar
# Processing Record 45 of Set 12 | abu kamal
# Processing Record 46 of Set 12 | barcelona
# Processing Record 47 of Set 12 | shache
# Processing Record 48 of Set 12 | namuac
# Processing Record 49 of Set 12 | pop
# Processing Record 50 of Set 12 | caceres
# Processing Record 1 of Set 13 | weyburn
# Processing Record 2 of Set 13 | paka
# Processing Record 3 of Set 13 | santa cecilia
# Processing Record 4 of Set 13 | fairbanks
# Processing Record 5 of Set 13 | mapastepec
# Processing Record 6 of Set 13 | maiduguri
# Processing Record 7 of Set 13 | santa cruz cabralia
# Processing Record 8 of Set 13 | verkhnyaya inta
# Processing Record 9 of Set 13 | umm lajj
# Processing Record 10 of Set 13 | nhulunbuy
# Processing Record 11 of Set 13 | kawalu
# Processing Record 12 of Set 13 | gandajika

# %%
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': 23.95, 'lat': -6.75},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 66.4,
#   'feels_like': 67.3,
#   'temp_min': 66.4,
#   'temp_max': 66.4,
#   'pressure': 1011,
#   'humidity': 97,
#   'sea_level': 1011,
#   'grnd_level': 921},
#  'visibility': 10000,
#  'wind': {'speed': 0.36, 'deg': 225, 'gust': 0.54},
#  'clouds': {'all': 99},
#  'dt': 1644460581,
#  'sys': {'country': 'CD', 'sunrise': 1644467285, 'sunset': 1644511735},
#  'timezone': 7200,
#  'id': 216449,
#  'name': 'Gandajika',
#  'cod': 200}

# %%
Practice = city_weather.json()
Practice["weather"][0]['description']
# Out:
# 'overcast clouds'

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.

print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | narsaq
# Processing Record 3 of Set 1 | cidreira
# Processing Record 4 of Set 1 | faanui
# Processing Record 5 of Set 1 | hilo
# Processing Record 6 of Set 1 | lagoa
# Processing Record 7 of Set 1 | san cristobal
# Processing Record 8 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 1 | vaini
# Processing Record 10 of Set 1 | sao joao da barra
# Processing Record 11 of Set 1 | lasa
# Processing Record 12 of Set 1 | ossora
# Processing Record 13 of Set 1 | utiroa
# City not found. Skipping...
# Processing Record 14 of Set 1 | tiksi
# Processing Record 15 of Set 1 | gisborne
# Processing Record 16 of Set 1 | bredasdorp
# Processing Record 17 of Set 1 | thompson
# Processing Record 18 of Set 1 | sakmara
# Processing Record 19 of Set 1 | camabatela
# Processing Record 20 of Set 1 | kapaa
# Processing Record 21 of Set 1 | hermanus
# Processing Record 22 of Set 1 | khudumelapye
# Processing Record 23 of Set 1 | rikitea
# Processing Record 24 of Set 1 | ushuaia
# Processing Record 25 of Set 1 | nalut
# Processing Record 26 of Set 1 | avarua
# Processing Record 27 of Set 1 | nanortalik
# Processing Record 28 of Set 1 | broken hill
# Processing Record 29 of Set 1 | pisco
# Processing Record 30 of Set 1 | colomi
# Processing Record 31 of Set 1 | birjand
# Processing Record 32 of Set 1 | heihe
# Processing Record 33 of Set 1 | butaritari
# Processing Record 34 of Set 1 | saskylakh
# Processing Record 35 of Set 1 | breyten
# Processing Record 36 of Set 1 | bluff
# Processing Record 37 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 38 of Set 1 | albany
# Processing Record 39 of Set 1 | puerto ayora
# Processing Record 40 of Set 1 | beian
# Processing Record 41 of Set 1 | kaitangata
# Processing Record 42 of Set 1 | uyuni
# Processing Record 43 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 44 of Set 1 | ancud
# Processing Record 45 of Set 1 | nikolskoye
# Processing Record 46 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 47 of Set 1 | mataura
# Processing Record 48 of Set 1 | castro
# Processing Record 49 of Set 1 | east london
# Processing Record 50 of Set 1 | atuona
# Processing Record 1 of Set 2 | half moon bay
# Processing Record 2 of Set 2 | hobart
# Processing Record 3 of Set 2 | colares
# Processing Record 4 of Set 2 | kavaratti
# Processing Record 5 of Set 2 | ponta do sol
# Processing Record 6 of Set 2 | cape town
# Processing Record 7 of Set 2 | dolbeau
# City not found. Skipping...
# Processing Record 8 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 9 of Set 2 | polovinnoye
# Processing Record 10 of Set 2 | mount gambier
# Processing Record 11 of Set 2 | kruisfontein
# Processing Record 12 of Set 2 | la seyne-sur-mer
# Processing Record 13 of Set 2 | port elizabeth
# Processing Record 14 of Set 2 | homer
# Processing Record 15 of Set 2 | tuktoyaktuk
# Processing Record 16 of Set 2 | port lincoln
# Processing Record 17 of Set 2 | manggar
# Processing Record 18 of Set 2 | tasiilaq
# Processing Record 19 of Set 2 | new norfolk
# Processing Record 20 of Set 2 | takoradi
# Processing Record 21 of Set 2 | jamestown
# Processing Record 22 of Set 2 | georgetown
# Processing Record 23 of Set 2 | alice springs
# Processing Record 24 of Set 2 | chiang khong
# Processing Record 25 of Set 2 | padang
# Processing Record 26 of Set 2 | klaksvik
# Processing Record 27 of Set 2 | saint-philippe
# Processing Record 28 of Set 2 | namibe
# Processing Record 29 of Set 2 | eidfjord
# Processing Record 30 of Set 2 | sokolo
# Processing Record 31 of Set 2 | damaturu
# Processing Record 32 of Set 2 | kahului
# Processing Record 33 of Set 2 | kodarma
# Processing Record 34 of Set 2 | linares
# Processing Record 35 of Set 2 | rosetown
# Processing Record 36 of Set 2 | lompoc
# Processing Record 37 of Set 2 | rio gallegos
# Processing Record 38 of Set 2 | biak
# Processing Record 39 of Set 2 | barrow
# Processing Record 40 of Set 2 | mahebourg
# Processing Record 41 of Set 2 | minot
# Processing Record 42 of Set 2 | altay
# Processing Record 43 of Set 2 | auki
# Processing Record 44 of Set 2 | dakar
# Processing Record 45 of Set 2 | naze
# Processing Record 46 of Set 2 | san pedro
# Processing Record 47 of Set 2 | hithadhoo
# Processing Record 48 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 49 of Set 2 | arlit
# Processing Record 50 of Set 2 | guadalupe y calvo
# Processing Record 1 of Set 3 | the valley
# Processing Record 2 of Set 3 | la palma
# Processing Record 3 of Set 3 | halifax
# Processing Record 4 of Set 3 | manaquiri
# Processing Record 5 of Set 3 | severo-kurilsk
# Processing Record 6 of Set 3 | vila
# Processing Record 7 of Set 3 | leningradskiy
# Processing Record 8 of Set 3 | russell
# Processing Record 9 of Set 3 | waddan
# Processing Record 10 of Set 3 | katangli
# Processing Record 11 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 12 of Set 3 | zhigansk
# Processing Record 13 of Set 3 | upernavik
# Processing Record 14 of Set 3 | yellowknife
# Processing Record 15 of Set 3 | tessalit
# Processing Record 16 of Set 3 | itarema
# Processing Record 17 of Set 3 | chokurdakh
# Processing Record 18 of Set 3 | palmer
# Processing Record 19 of Set 3 | kemijarvi
# Processing Record 20 of Set 3 | ilulissat
# Processing Record 21 of Set 3 | road town
# Processing Record 22 of Set 3 | bambous virieux
# Processing Record 23 of Set 3 | qaanaaq
# Processing Record 24 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 25 of Set 3 | port augusta
# Processing Record 26 of Set 3 | fortuna
# Processing Record 27 of Set 3 | ladario
# Processing Record 28 of Set 3 | airai
# Processing Record 29 of Set 3 | vostok
# Processing Record 30 of Set 3 | mar del plata
# Processing Record 31 of Set 3 | ust-nera
# Processing Record 32 of Set 3 | yulara
# Processing Record 33 of Set 3 | esperance
# Processing Record 34 of Set 3 | hamilton
# Processing Record 35 of Set 3 | qaqortoq
# Processing Record 36 of Set 3 | pacific grove
# Processing Record 37 of Set 3 | springfield
# Processing Record 38 of Set 3 | huejuquilla el alto
# Processing Record 39 of Set 3 | rio tercero
# Processing Record 40 of Set 3 | pevek
# Processing Record 41 of Set 3 | russkiy aktash
# Processing Record 42 of Set 3 | avera
# Processing Record 43 of Set 3 | busselton
# Processing Record 44 of Set 3 | deputatskiy
# Processing Record 45 of Set 3 | jumla
# Processing Record 46 of Set 3 | wanaka
# Processing Record 47 of Set 3 | noyabrsk
# Processing Record 48 of Set 3 | agadez
# Processing Record 49 of Set 3 | port alfred
# Processing Record 50 of Set 3 | san angelo
# Processing Record 1 of Set 4 | kalianget
# Processing Record 2 of Set 4 | kindu
# Processing Record 3 of Set 4 | new castle
# Processing Record 4 of Set 4 | novoagansk
# Processing Record 5 of Set 4 | saldanha
# Processing Record 6 of Set 4 | bethel
# Processing Record 7 of Set 4 | jabiru
# City not found. Skipping...
# Processing Record 8 of Set 4 | ferrol
# Processing Record 9 of Set 4 | progreso
# Processing Record 10 of Set 4 | leninsk
# Processing Record 11 of Set 4 | ilinskiy
# Processing Record 12 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 4 | los llanos de aridane
# Processing Record 14 of Set 4 | buala
# Processing Record 15 of Set 4 | kaohsiung
# Processing Record 16 of Set 4 | carnarvon
# Processing Record 17 of Set 4 | maraa
# Processing Record 18 of Set 4 | pafos
# Processing Record 19 of Set 4 | bandar-e anzali
# Processing Record 20 of Set 4 | riyadh
# Processing Record 21 of Set 4 | mehamn
# Processing Record 22 of Set 4 | ahipara
# Processing Record 23 of Set 4 | khash
# Processing Record 24 of Set 4 | mmathubudukwane
# Processing Record 25 of Set 4 | ushtobe
# Processing Record 26 of Set 4 | cruz alta
# Processing Record 27 of Set 4 | grindavik
# Processing Record 28 of Set 4 | akyab
# Processing Record 29 of Set 4 | napoleon
# Processing Record 30 of Set 4 | talcahuano
# Processing Record 31 of Set 4 | cockburn town
# Processing Record 32 of Set 4 | khatanga
# Processing Record 33 of Set 4 | san patricio
# Processing Record 34 of Set 4 | vila velha
# Processing Record 35 of Set 4 | laguna
# Processing Record 36 of Set 4 | ribeira grande
# Processing Record 37 of Set 4 | geraldton
# Processing Record 38 of Set 4 | college
# Processing Record 39 of Set 4 | altar
# Processing Record 40 of Set 4 | ormara
# Processing Record 41 of Set 4 | lavrentiya
# Processing Record 42 of Set 4 | sambava
# Processing Record 43 of Set 4 | perle
# Processing Record 44 of Set 4 | jensen beach
# Processing Record 45 of Set 4 | torbay
# Processing Record 46 of Set 4 | casper
# Processing Record 47 of Set 4 | bosobolo
# Processing Record 48 of Set 4 | quesnel
# Processing Record 49 of Set 4 | kovdor
# Processing Record 50 of Set 4 | dikson
# Processing Record 1 of Set 5 | cap malheureux
# Processing Record 2 of Set 5 | komsomolskiy
# Processing Record 3 of Set 5 | sao filipe
# Processing Record 4 of Set 5 | yumen
# Processing Record 5 of Set 5 | montepuez
# Processing Record 6 of Set 5 | cabo san lucas
# Processing Record 7 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 8 of Set 5 | huarmey
# Processing Record 9 of Set 5 | kommunisticheskiy
# Processing Record 10 of Set 5 | norman wells
# Processing Record 11 of Set 5 | kodiak
# Processing Record 12 of Set 5 | dentsville
# Processing Record 13 of Set 5 | kendari
# Processing Record 14 of Set 5 | souillac
# Processing Record 15 of Set 5 | comodoro rivadavia
# Processing Record 16 of Set 5 | ukiah
# Processing Record 17 of Set 5 | lebu
# Processing Record 18 of Set 5 | maceio
# Processing Record 19 of Set 5 | ternate
# Processing Record 20 of Set 5 | te anau
# Processing Record 21 of Set 5 | honiara
# Processing Record 22 of Set 5 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 23 of Set 5 | waingapu
# Processing Record 24 of Set 5 | sola
# Processing Record 25 of Set 5 | raudeberg
# Processing Record 26 of Set 5 | santa lucia
# Processing Record 27 of Set 5 | port hedland
# Processing Record 28 of Set 5 | quatre cocos
# Processing Record 29 of Set 5 | guerrero negro
# Processing Record 30 of Set 5 | victoria
# Processing Record 31 of Set 5 | lieksa
# Processing Record 32 of Set 5 | hualmay
# Processing Record 33 of Set 5 | fort nelson
# Processing Record 34 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 35 of Set 5 | meulaboh
# Processing Record 36 of Set 5 | gemena
# Processing Record 37 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 38 of Set 5 | dunmore town
# Processing Record 39 of Set 5 | wajima
# Processing Record 40 of Set 5 | leh
# Processing Record 41 of Set 5 | sitka
# Processing Record 42 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 43 of Set 5 | kisangani
# Processing Record 44 of Set 5 | longyearbyen
# Processing Record 45 of Set 5 | banda aceh
# Processing Record 46 of Set 5 | surt
# Processing Record 47 of Set 5 | canyon
# Processing Record 48 of Set 5 | strezhevoy
# Processing Record 49 of Set 5 | juifang
# City not found. Skipping...
# Processing Record 50 of Set 5 | moerai
# Processing Record 1 of Set 6 | dillon
# Processing Record 2 of Set 6 | vanimo
# Processing Record 3 of Set 6 | trat
# Processing Record 4 of Set 6 | kut chap
# Processing Record 5 of Set 6 | vardo
# Processing Record 6 of Set 6 | olovyannaya
# Processing Record 7 of Set 6 | gladstone
# Processing Record 8 of Set 6 | terrasini
# Processing Record 9 of Set 6 | hasaki
# Processing Record 10 of Set 6 | kuandian
# Processing Record 11 of Set 6 | rawannawi
# City not found. Skipping...
# Processing Record 12 of Set 6 | havre-saint-pierre
# Processing Record 13 of Set 6 | arraial do cabo
# Processing Record 14 of Set 6 | sao jose da coroa grande
# Processing Record 15 of Set 6 | kieta
# Processing Record 16 of Set 6 | vaitape
# Processing Record 17 of Set 6 | epe
# Processing Record 18 of Set 6 | ambon
# Processing Record 19 of Set 6 | demba
# Processing Record 20 of Set 6 | ponta delgada
# Processing Record 21 of Set 6 | beringovskiy
# Processing Record 22 of Set 6 | porkhov
# Processing Record 23 of Set 6 | emerald
# Processing Record 24 of Set 6 | osakarovka
# Processing Record 25 of Set 6 | hanmer springs
# Processing Record 26 of Set 6 | san ramon
# Processing Record 27 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 28 of Set 6 | tateyama
# Processing Record 29 of Set 6 | ondangwa
# Processing Record 30 of Set 6 | tanout
# Processing Record 31 of Set 6 | ellisras
# Processing Record 32 of Set 6 | port hardy
# Processing Record 33 of Set 6 | charlestown
# Processing Record 34 of Set 6 | tanabe
# Processing Record 35 of Set 6 | peniche
# Processing Record 36 of Set 6 | port hawkesbury
# Processing Record 37 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 38 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 39 of Set 6 | dingle
# Processing Record 40 of Set 6 | nome
# Processing Record 41 of Set 6 | bilma
# Processing Record 42 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 43 of Set 6 | tarpon springs
# Processing Record 44 of Set 6 | gumushane
# City not found. Skipping...
# Processing Record 45 of Set 6 | ulagan
# Processing Record 46 of Set 6 | grand centre
# City not found. Skipping...
# Processing Record 47 of Set 6 | seymchan
# Processing Record 48 of Set 6 | nishihara
# Processing Record 49 of Set 6 | inta
# Processing Record 50 of Set 6 | flin flon
# Processing Record 1 of Set 7 | chuy
# Processing Record 2 of Set 7 | mumbwa
# Processing Record 3 of Set 7 | acarau
# Processing Record 4 of Set 7 | lorica
# Processing Record 5 of Set 7 | coihaique
# Processing Record 6 of Set 7 | bonavista
# Processing Record 7 of Set 7 | pudozh
# Processing Record 8 of Set 7 | villazon
# Processing Record 9 of Set 7 | parakan
# Processing Record 10 of Set 7 | valleyview
# Processing Record 11 of Set 7 | saint-pierre
# Processing Record 12 of Set 7 | kavieng
# Processing Record 13 of Set 7 | zvolen
# Processing Record 14 of Set 7 | minuri
# Processing Record 15 of Set 7 | sauca
# Processing Record 16 of Set 7 | sungairaya
# Processing Record 17 of Set 7 | itoman
# Processing Record 18 of Set 7 | kuryk
# Processing Record 19 of Set 7 | charters towers
# Processing Record 20 of Set 7 | kismayo
# Processing Record 21 of Set 7 | grand gaube
# Processing Record 22 of Set 7 | enumclaw
# Processing Record 23 of Set 7 | vitim
# Processing Record 24 of Set 7 | antalaha
# Processing Record 25 of Set 7 | cayenne
# Processing Record 26 of Set 7 | buraydah
# Processing Record 27 of Set 7 | anzio
# Processing Record 28 of Set 7 | huazolotitlan
# City not found. Skipping...
# Processing Record 29 of Set 7 | grand-santi
# Processing Record 30 of Set 7 | san carlos del zulia
# Processing Record 31 of Set 7 | weligama
# Processing Record 32 of Set 7 | yining
# Processing Record 33 of Set 7 | lima
# Processing Record 34 of Set 7 | bubaque
# Processing Record 35 of Set 7 | goderich
# Processing Record 36 of Set 7 | dhanera
# Processing Record 37 of Set 7 | nicolas bravo
# Processing Record 38 of Set 7 | cherskiy
# Processing Record 39 of Set 7 | aksarka
# Processing Record 40 of Set 7 | yar-sale
# Processing Record 41 of Set 7 | kharan
# Processing Record 42 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 43 of Set 7 | straumen
# Processing Record 44 of Set 7 | dzhusaly
# City not found. Skipping...
# Processing Record 45 of Set 7 | laurel
# Processing Record 46 of Set 7 | lac du bonnet
# Processing Record 47 of Set 7 | provideniya
# Processing Record 48 of Set 7 | palana
# Processing Record 49 of Set 7 | moron
# Processing Record 50 of Set 7 | javanrud
# Processing Record 1 of Set 8 | san quintin
# Processing Record 2 of Set 8 | bandarbeyla
# Processing Record 3 of Set 8 | rocha
# Processing Record 4 of Set 8 | boqueirao
# Processing Record 5 of Set 8 | toftir
# City not found. Skipping...
# Processing Record 6 of Set 8 | san-pedro
# Processing Record 7 of Set 8 | lodwar
# Processing Record 8 of Set 8 | monteria
# Processing Record 9 of Set 8 | constitucion
# Processing Record 10 of Set 8 | abha
# Processing Record 11 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 12 of Set 8 | grande prairie
# Processing Record 13 of Set 8 | milan
# Processing Record 14 of Set 8 | dukat
# Processing Record 15 of Set 8 | ampanihy
# Processing Record 16 of Set 8 | ritchie
# Processing Record 17 of Set 8 | fukuma
# Processing Record 18 of Set 8 | esso
# Processing Record 19 of Set 8 | umm durman
# City not found. Skipping...
# Processing Record 20 of Set 8 | damoh
# Processing Record 21 of Set 8 | terra santa
# Processing Record 22 of Set 8 | luganville
# Processing Record 23 of Set 8 | talaya
# Processing Record 24 of Set 8 | svetlaya
# Processing Record 25 of Set 8 | sibolga
# Processing Record 26 of Set 8 | bismarck
# Processing Record 27 of Set 8 | lumby
# Processing Record 28 of Set 8 | zyryanka
# Processing Record 29 of Set 8 | marawi
# Processing Record 30 of Set 8 | evanston
# Processing Record 31 of Set 8 | hobyo
# Processing Record 32 of Set 8 | tocopilla
# Processing Record 33 of Set 8 | makungu
# Processing Record 34 of Set 8 | dali
# Processing Record 35 of Set 8 | ust-kan
# Processing Record 36 of Set 8 | trinidad
# Processing Record 37 of Set 8 | srivardhan
# Processing Record 38 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 39 of Set 8 | kasempa
# Processing Record 40 of Set 8 | port dickson
# Processing Record 41 of Set 8 | verkhnevilyuysk
# Processing Record 42 of Set 8 | erdenet
# Processing Record 43 of Set 8 | bathsheba
# Processing Record 44 of Set 8 | turtkul
# City not found. Skipping...
# Processing Record 45 of Set 8 | hailar
# Processing Record 46 of Set 8 | rundu
# Processing Record 47 of Set 8 | marsaxlokk
# Processing Record 48 of Set 8 | jarjis
# City not found. Skipping...
# Processing Record 49 of Set 8 | touros
# Processing Record 50 of Set 8 | orai
# Processing Record 1 of Set 9 | ostrovnoy
# Processing Record 2 of Set 9 | shush
# Processing Record 3 of Set 9 | barra patuca
# Processing Record 4 of Set 9 | mrakovo
# Processing Record 5 of Set 9 | visby
# Processing Record 6 of Set 9 | urdzhar
# City not found. Skipping...
# Processing Record 7 of Set 9 | barabai
# Processing Record 8 of Set 9 | presidente dutra
# Processing Record 9 of Set 9 | saint george
# Processing Record 10 of Set 9 | vanavara
# Processing Record 11 of Set 9 | nuuk
# Processing Record 12 of Set 9 | atar
# Processing Record 13 of Set 9 | sattahip
# Processing Record 14 of Set 9 | katsuura
# Processing Record 15 of Set 9 | praia da vitoria
# Processing Record 16 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 17 of Set 9 | amarpur
# Processing Record 18 of Set 9 | shushtar
# Processing Record 19 of Set 9 | mindelo
# Processing Record 20 of Set 9 | prince george
# Processing Record 21 of Set 9 | ngunguru
# Processing Record 22 of Set 9 | mogilno
# Processing Record 23 of Set 9 | jambi
# Processing Record 24 of Set 9 | tholen
# Processing Record 25 of Set 9 | linxia
# Processing Record 26 of Set 9 | melo
# Processing Record 27 of Set 9 | puerto del rosario
# Processing Record 28 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 29 of Set 9 | tambul
# City not found. Skipping...
# Processing Record 30 of Set 9 | karkaralinsk
# City not found. Skipping...
# Processing Record 31 of Set 9 | galveston
# Processing Record 32 of Set 9 | nuevitas
# Processing Record 33 of Set 9 | numan
# Processing Record 34 of Set 9 | umtata
# Processing Record 35 of Set 9 | northam
# Processing Record 36 of Set 9 | labuhan
# Processing Record 37 of Set 9 | ulaangom
# Processing Record 38 of Set 9 | benguela
# Processing Record 39 of Set 9 | komarikhinskiy
# Processing Record 40 of Set 9 | formosa do rio preto
# Processing Record 41 of Set 9 | copala
# Processing Record 42 of Set 9 | chapais
# Processing Record 43 of Set 9 | stromness
# Processing Record 44 of Set 9 | parras
# City not found. Skipping...
# Processing Record 45 of Set 9 | berlevag
# Processing Record 46 of Set 9 | labutta
# City not found. Skipping...
# Processing Record 47 of Set 9 | erenhot
# Processing Record 48 of Set 9 | balimo
# City not found. Skipping...
# Processing Record 49 of Set 9 | jinchang
# Processing Record 50 of Set 9 | killybegs
# Processing Record 1 of Set 10 | paamiut
# Processing Record 2 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 3 of Set 10 | husavik
# Processing Record 4 of Set 10 | faya
# Processing Record 5 of Set 10 | dimona
# Processing Record 6 of Set 10 | vestmanna
# Processing Record 7 of Set 10 | calatayud
# Processing Record 8 of Set 10 | ondorhaan
# City not found. Skipping...
# Processing Record 9 of Set 10 | margate
# Processing Record 10 of Set 10 | sheregesh
# Processing Record 11 of Set 10 | ballina
# Processing Record 12 of Set 10 | igarka
# Processing Record 13 of Set 10 | uglovskoye
# Processing Record 14 of Set 10 | edgewater
# Processing Record 15 of Set 10 | olafsvik
# Processing Record 16 of Set 10 | atambua
# Processing Record 17 of Set 10 | kloulklubed
# Processing Record 18 of Set 10 | bacuit
# City not found. Skipping...
# Processing Record 19 of Set 10 | marsh harbour
# Processing Record 20 of Set 10 | hambantota
# Processing Record 21 of Set 10 | tezu
# Processing Record 22 of Set 10 | gushikawa
# Processing Record 23 of Set 10 | krabi
# Processing Record 24 of Set 10 | zeya
# Processing Record 25 of Set 10 | repnoye
# Processing Record 26 of Set 10 | samandag
# Processing Record 27 of Set 10 | alexandria
# Processing Record 28 of Set 10 | saint-augustin
# Processing Record 29 of Set 10 | dicabisagan
# Processing Record 30 of Set 10 | copperas cove
# Processing Record 31 of Set 10 | pangoa
# Processing Record 32 of Set 10 | mbandaka
# Processing Record 33 of Set 10 | vryburg
# Processing Record 34 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 35 of Set 10 | jalu
# Processing Record 36 of Set 10 | abu dhabi
# Processing Record 37 of Set 10 | kumylzhenskaya
# Processing Record 38 of Set 10 | saint anthony
# Processing Record 39 of Set 10 | luzhou
# Processing Record 40 of Set 10 | richards bay
# Processing Record 41 of Set 10 | shitanjing
# Processing Record 42 of Set 10 | patan
# Processing Record 43 of Set 10 | tuatapere
# Processing Record 44 of Set 10 | codrington
# Processing Record 45 of Set 10 | show low
# Processing Record 46 of Set 10 | nabire
# Processing Record 47 of Set 10 | tautira
# Processing Record 48 of Set 10 | lucknow
# Processing Record 49 of Set 10 | vagur
# Processing Record 50 of Set 10 | guararapes
# Processing Record 1 of Set 11 | turayf
# Processing Record 2 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 3 of Set 11 | puerto colombia
# Processing Record 4 of Set 11 | giyon
# Processing Record 5 of Set 11 | atasu
# Processing Record 6 of Set 11 | lorengau
# Processing Record 7 of Set 11 | nizwa
# Processing Record 8 of Set 11 | jiddah
# City not found. Skipping...
# Processing Record 9 of Set 11 | koslan
# Processing Record 10 of Set 11 | kaligutan
# Processing Record 11 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 12 of Set 11 | hofn
# Processing Record 13 of Set 11 | magdagachi
# Processing Record 14 of Set 11 | buchanan
# Processing Record 15 of Set 11 | bilibino
# Processing Record 16 of Set 11 | belaya gora
# Processing Record 17 of Set 11 | tawkar
# City not found. Skipping...
# Processing Record 18 of Set 11 | trelew
# Processing Record 19 of Set 11 | shaoyang
# Processing Record 20 of Set 11 | caborca
# Processing Record 21 of Set 11 | billings
# Processing Record 22 of Set 11 | port blair
# Processing Record 23 of Set 11 | poso
# Processing Record 24 of Set 11 | westport
# Processing Record 25 of Set 11 | mtwara
# Processing Record 26 of Set 11 | sioux lookout
# Processing Record 27 of Set 11 | sarangani
# Processing Record 28 of Set 11 | harrison
# Processing Record 29 of Set 11 | orje
# Processing Record 30 of Set 11 | stokmarknes
# Processing Record 31 of Set 11 | teahupoo
# Processing Record 32 of Set 11 | sayyan
# Processing Record 33 of Set 11 | paulo ramos
# Processing Record 34 of Set 11 | santa cruz
# Processing Record 35 of Set 11 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 36 of Set 11 | kondoa
# Processing Record 37 of Set 11 | raduzhnyy
# Processing Record 38 of Set 11 | bikaner
# Processing Record 39 of Set 11 | clyde river
# Processing Record 40 of Set 11 | markova
# Processing Record 41 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 42 of Set 11 | alba
# Processing Record 43 of Set 11 | pangody
# Processing Record 44 of Set 11 | monrovia
# Processing Record 45 of Set 11 | oum hadjer
# Processing Record 46 of Set 11 | soyo
# Processing Record 47 of Set 11 | manavalakurichi
# Processing Record 48 of Set 11 | ulladulla
# Processing Record 49 of Set 11 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 50 of Set 11 | necochea
# Processing Record 1 of Set 12 | hanyang
# Processing Record 2 of Set 12 | oistins
# Processing Record 3 of Set 12 | ouallam
# Processing Record 4 of Set 12 | salalah
# Processing Record 5 of Set 12 | san agustin
# Processing Record 6 of Set 12 | samarai
# Processing Record 7 of Set 12 | taywarah
# Processing Record 8 of Set 12 | karratha
# Processing Record 9 of Set 12 | jining
# Processing Record 10 of Set 12 | virginia beach
# Processing Record 11 of Set 12 | lamu
# Processing Record 12 of Set 12 | evensk
# Processing Record 13 of Set 12 | anadyr
# Processing Record 14 of Set 12 | gat
# Processing Record 15 of Set 12 | kamenka
# Processing Record 16 of Set 12 | oriximina
# Processing Record 17 of Set 12 | broome
# Processing Record 18 of Set 12 | naifaru
# Processing Record 19 of Set 12 | mgandu
# Processing Record 20 of Set 12 | lungi
# Processing Record 21 of Set 12 | sibenik
# Processing Record 22 of Set 12 | robertsport
# Processing Record 23 of Set 12 | zhuhai
# Processing Record 24 of Set 12 | nobeoka
# Processing Record 25 of Set 12 | sakakah
# Processing Record 26 of Set 12 | antropovo
# Processing Record 27 of Set 12 | krasnoselkup
# Processing Record 28 of Set 12 | ihosy
# Processing Record 29 of Set 12 | mokhsogollokh
# Processing Record 30 of Set 12 | ariquemes
# Processing Record 31 of Set 12 | kiunga
# Processing Record 32 of Set 12 | aykhal
# Processing Record 33 of Set 12 | bonthe
# Processing Record 34 of Set 12 | severnyy
# Processing Record 35 of Set 12 | tecoanapa
# Processing Record 36 of Set 12 | rapar
# Processing Record 37 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 38 of Set 12 | poopo
# Processing Record 39 of Set 12 | wanning
# Processing Record 40 of Set 12 | cornelio procopio
# Processing Record 41 of Set 12 | ust-barguzin
# Processing Record 42 of Set 12 | coahuayana
# Processing Record 43 of Set 12 | presidencia roque saenz pena
# Processing Record 44 of Set 12 | adrar
# Processing Record 45 of Set 12 | abu kamal
# Processing Record 46 of Set 12 | barcelona
# Processing Record 47 of Set 12 | shache
# Processing Record 48 of Set 12 | namuac
# Processing Record 49 of Set 12 | pop
# Processing Record 50 of Set 12 | caceres
# Processing Record 1 of Set 13 | weyburn
# Processing Record 2 of Set 13 | paka
# Processing Record 3 of Set 13 | santa cecilia
# Processing Record 4 of Set 13 | fairbanks
# Processing Record 5 of Set 13 | mapastepec
# Processing Record 6 of Set 13 | maiduguri
# Processing Record 7 of Set 13 | santa cruz cabralia
# Processing Record 8 of Set 13 | verkhnyaya inta
# Processing Record 9 of Set 13 | umm lajj
# Processing Record 10 of Set 13 | nhulunbuy
# Processing Record 11 of Set 13 | kawalu
# Processing Record 12 of Set 13 | gandajika
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
import pandas as pd

# %%
city_weather_df = pd.DataFrame(city_data)

# %%
city_weather_df.head(10)
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0       Punta Arenas      CL -53.1500  -70.9167     44.71        65
# 1             Narsaq      GL  60.9167  -46.0500     14.22        69
# 2           Cidreira      BR -30.1811  -50.2056     72.07        72
# 3             Faanui      PF -16.4833 -151.7500     81.34        76
# 4               Hilo      US  19.7297 -155.0900     72.81        88
# 5              Lagoa      PT  39.0500  -27.9833     58.28        70
# 6      San Cristobal      VE   7.7669  -72.2250     71.78        93
# 7              Vaini      TO -21.2000 -175.2000     80.47        83
# 8  Sao Joao Da Barra      BR -21.6403  -41.0511     68.52        96
# 9               Lasa      IT  46.6166   10.7002     32.29        36
#
#    Cloudiness  Wind Speed Weather Description
# 0          40       21.85    scattered clouds
# 1          82       10.00       broken clouds
# 2          93       13.42     overcast clouds
# 3          80       14.20          light rain
# 4          35        4.29    scattered clouds
# 5           0       14.83           clear sky
# 6          97        1.36     overcast clouds
# 7          20       20.31          light rain
# 8         100        9.57          light rain
# 9          34        3.29    scattered clouds

# %%
# Create the output file (CSV).

output_data_file = "/Users/lisahanson/desktop/class/api/weather_database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_weather_df.to_csv(output_data_file, index_label="City_ID")
